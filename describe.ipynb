# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarroyhan69-gif/running-pace-analyst-/blob/main/describe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
d= pd.read_excel("/content/sfx.xlsx")
d.head()
# Out:
#                 Timestamp                                  Email Address  \
# 0 2025-05-15 06:01:09.244                          anggamarifat@gmai.com
# 1 2025-05-15 06:27:24.613  iqbalhidayah40@student.iqt.unida.gontor.ac.id
# 2 2025-05-15 11:35:53.068                              hzidniy@gmail.com
# 3 2025-05-20 21:29:14.949                       qberabdillah14@gmail.com
# 4 2025-05-21 06:19:53.757                         mbayusantoso@gmail.com
#
#    Score                   Name  \
# 0    0.0           Pujangga aji
# 1    0.0          Iqbal hidayah
# 2    0.0                 Zidniy
# 3    0.0          Akbar abdilah
# 4    0.0  Muhammad Bayu santoso
#
#                                            Email  semester usia  pace berat  \
# 0                          anggamarifat@gmai.com       7.0   22   8.0    68
# 1  iqbalhidayah40@student.iqt.unida.gontor.ac.id       7.0   23   4.0    56
# 2                              hzidniy@gmail.com       7.0   20   5.0    49
# ...

# %%
kolom = [
    "semester",
    "usia",
    "pace",
    "berat",
    "tinggi",
    "latihan_per_minggu",
    "perokok"
]
slc = d[kolom]
slc.describe()
# Out:
#          semester        pace      tinggi  latihan_per_minggu     perokok
# count  115.000000  115.000000  115.000000          115.000000  115.000000
# mean     2.982609    8.348609  165.686957            2.739130    0.173913
# std      2.645694    3.781446    6.395400            1.504887    0.380693
# min      1.000000    3.000000  144.000000            1.000000    0.000000
# 25%      1.000000    5.245000  162.000000            1.500000    0.000000
# 50%      1.000000    7.000000  166.000000            3.000000    0.000000
# 75%      6.500000   10.000000  170.000000            3.500000    0.000000
# max      7.000000   18.000000  178.000000            7.000000    1.000000
